# %%
# !pip install fastapi
# !pip install uvicorn
# !pip install pickle5
# !pip install pydantic
# !pip install scikit-learn
# !pip install requests
# !pip install pypi-json
# !pip install pyngrok
# !pip install nest-asyncio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 10.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 35.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 40.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 89.2 MB/s eta 0:00:00
# ...

# %%
from fastapi import FastAPI
from pydantic import BaseModel
import pickle
import json
import uvicorn
from pyngrok import ngrok
from fastapi.middleware.cors import CORSMiddleware
import nest_asyncio
app = FastAPI()
origins = ["*"]

app.add_middleware(
    CORSMiddleware,
    allow_origins=origins,
    allow_credentials=True,
    allow_methods=["*"],
    allow_headers=["*"],
)
class model_input(BaseModel):

    Post : str

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/ChefGPT')
# Out:
# Mounted at /content/drive

# %%
import torch
import numpy as np
from torch.autograd import Variable
from tqdm import tqdm_notebook as tqdm

class MatrixFactorization(torch.nn.Module):
    def __init__(self, n_users, n_items, n_factors=20):
        super().__init__()
        # create user embeddings
        self.user_factors = torch.nn.Embedding(n_users, n_factors) # think of this as a lookup table for the input.
        # create item embeddings
        self.item_factors = torch.nn.Embedding(n_items, n_factors) # think of this as a lookup table for the input.
        self.user_factors.weight.data.uniform_(0, 0.05)
        self.item_factors.weight.data.uniform_(0, 0.05)

    def forward(self, data):
        # matrix multiplication
        users, items = data[:,0], data[:,1]
        return (self.user_factors(users)*self.item_factors(items)).sum(1)
    # def forward(self, user, item):
    # 	# matrix multiplication
    #     return (self.user_factors(user)*self.item_factors(item)).sum(1)

    def predict(self, user, item):
        return self.forward(user, item)

# %%
def get_cluster_elements(input_food_id, kmeans_model, embeddings, dataset):
    # Predict the cluster label of the input food ID
    if input_food_id not in dataset.foodid2idx:
        print("Input food ID not found.")
        return []

    input_food_idx = dataset.foodid2idx[input_food_id]
    cluster_label = kmeans_model.predict(embeddings[input_food_idx].reshape(1, -1))

    # Find all food IDs belonging to the same cluster
    cluster_food_ids = []
    for idx, label in enumerate(kmeans_model.labels_):
        if label == cluster_label:
            food_id = dataset.idx2foodid[idx]
            cluster_food_ids.append(food_id)

    return cluster_food_ids

# %%
# Creating the dataloader (necessary for PyTorch)
from torch.utils.data.dataset import Dataset
from torch.utils.data import DataLoader # package that helps transform your data to machine learning readiness

# Note: This isn't 'good' practice, in a MLops sense but we'll roll with this since the data is already loaded in memory.
class Loader(Dataset):
    def __init__(self):
        self.swipes = user_interaction_df.copy()

        # Extract all user IDs and movie IDs
        users = user_interaction_df.user_id.unique()
        foods = user_interaction_df.food_id.unique()

        #--- Producing new continuous IDs for users and movies ---

        # Unique values : index
        self.userid2idx = {o:i for i,o in enumerate(users)}
        self.foodid2idx = {o:i for i,o in enumerate(foods)}

        # Obtained continuous ID for users and movies
        self.idx2userid = {i:o for o,i in self.userid2idx.items()}
        self.idx2foodid = {i:o for o,i in self.foodid2idx.items()}

        # return the id from the indexed values as noted in the lambda function down below.
        self.swipes.food_id = user_interaction_df.food_id.apply(lambda x: self.foodid2idx[x])
        self.swipes.user_id = user_interaction_df.user_id.apply(lambda x: self.userid2idx[x])


        self.x = self.swipes.drop(['swiped', 'liked'], axis=1).values
        self.y = self.swipes['swiped'].values
        self.x, self.y = torch.tensor(self.x), torch.tensor(self.y) # Transforms the data to tensors (ready for torch models.)

    def __getitem__(self, index):
        return (self.x[index], self.y[index])

    def __len__(self):
        return len(self.swipes)

# %%
# loading the saved model
kmeans_model = pickle.load(open('/content/drive/My Drive/ChefGPT/kmeans_final_model.pkl', 'rb'))
n_users =399
n_items =3550
# Initialize the model
model = MatrixFactorization(n_users, n_items, n_factors=8)

model_path = '/content/drive/My Drive/ChefGPT/matrix_factorization_model.pth'
model.load_state_dict(torch.load(model_path, map_location=torch.device('cpu')))

# # If you're using GPU, move the model to GPU
# if cuda:
#     model = model.cuda()
import pandas as pd
food_df = pd.read_csv('posts.csv')
user_df = pd.read_csv('users.csv')
user_interaction_df = pd.read_csv('user_interaction.csv')

trained_food_embeddings = model.item_factors.weight.data.cpu().numpy()

train_set = Loader()
food_names = food_df.set_index('food_id')['dishName'].to_dict()

# %%
# !ngrok authtoken 2g067pDPFcRHFzdd4fMui74JJ9X_76AVeLNc4omXj3ks8kJcf
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import json
from fastapi import FastAPI
from pyngrok import ngrok
import nest_asyncio
import uvicorn

# Assuming you have defined your FastAPI app
app = FastAPI()

@app.post('/kmeans_prediction')
async def kmeans_predddd(input_parameters: dict):
    input_food_id = input_parameters["input_food_id"]  # Get the input ID from the request body

    # Simulated functions for demonstration, replace with actual implementations
    cluster_food_names = get_cluster_elements(input_food_id, kmeans_model, trained_food_embeddings, train_set)

    # Get the top 2 cluster food names
    top_2_cluster_food_names = cluster_food_names[:2]

    # Print the top 2 cluster food names
    print("Top 2 food names belonging to the same cluster as the input food ID:")
    for food_name in top_2_cluster_food_names:
        print("\t", food_name)

    return top_2_cluster_food_names


# Set up ngrok tunnel
ngrok_tunnel = ngrok.connect(8000)
print('Public URL:', ngrok_tunnel.public_url)

# Run the server
nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# Public URL: https://02ee-34-142-191-177.ngrok-free.app
# INFO:     Started server process [337]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# Top 2 food names belonging to the same cluster as the input food ID:
# 	 -Nwy60_VjeItlz5DdvjV
# 	 -Nwy6WRxj-e1-lSfPlnL
# INFO:     115.244.221.146:0 - "POST /kmeans_prediction HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [337]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-0a3ce139039f> in <cell line: 34>()
#      32 # Run the server
#      33 nest_asyncio.apply()
# ---> 34 uvicorn.run(app, port=8000)
#
# ...

# %%
import json
from fastapi import FastAPI
from pyngrok import ngrok
import nest_asyncio
import uvicorn

# Assuming you have defined your FastAPI app
app = FastAPI()


@app.post('/kmeans_prediction')
async def kmeans_predddd(input_parameters: dict):
    input_food_id = input_parameters["input_food_id"]  # Get the input ID from the request body
    user_id = input_parameters["user_id"]  # Get the user ID from the request body
    interaction_file_path = 'user_interaction.csv'
    user_interaction_df = pd.read_csv(interaction_file_path)
    user_interacted_foods = user_interaction_df[user_interaction_df['user_id'] == user_id]['food_id'].tolist()
    # Simulated functions for demonstration, replace with actual implementations
    cluster_food_names = get_cluster_elements(input_food_id, kmeans_model, trained_food_embeddings, train_set)

    # Filter out food items that the user has already interacted with
    unseen_food_names = [food_name for food_name in cluster_food_names if food_name not in user_interacted_foods]

    # Get the top 2 unseen cluster food names
    top_2_unseen_cluster_food_names = unseen_food_names[:2]

    # Print the top 2 unseen cluster food names
    print("Top 2 unseen food names belonging to the same cluster as the input food ID:")
    for food_name in top_2_unseen_cluster_food_names:
        print("\t", food_name)
    for i in cluster_food_names:
      x=cluster_food_names.index(i)
      i=i.replace("-","")
      cluster_food_names[x]=i
      print(i)
    print(cluster_food_names)

    posts_df = pd.read_csv('posts.csv')  # Read posts.csv
    cluster_posts = posts_df[posts_df['food_id'].isin(cluster_food_names)]  # Filter posts belonging to the cluster

    if not cluster_posts.empty:  # Check if cluster_posts is not empty
        # Select the last entry from the filtered posts
        last_post = cluster_posts.tail(1).iloc[0]

        # Get the food ID of the recommended post
        recommended_post_id = last_post['food_id']
    else:
        recommended_post_id = None  # If no posts found, return None

    recom=top_2_unseen_cluster_food_names+recommended_post_id
    return recom

# Set up ngrok tunnel

    #return top_2_unseen_cluster_food_names


# Set up ngrok tunnel
ngrok_tunnel = ngrok.connect(5000)
print('Public URL:', ngrok_tunnel.public_url)

# Run the server
nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# ERROR:pyngrok.process.ngrok:t=2024-05-05T13:11:03+0000 lvl=eror msg="failed to reconnect session" obj=tunnels.session err="authentication failed: Your account is limited to 1 simultaneous ngrok agent sessions.\nYou can run multiple tunnels on a single agent session using a configuration file.\nTo learn more, see https://ngrok.com/docs/secure-tunnels/ngrok-agent/reference/config/\nYou can view your current agent sessions in the dashboard:\nhttps://dashboard.ngrok.com/tunnels/agents\r\n\r\nERR_NGROK_108\r\n"
# ...
